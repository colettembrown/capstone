# %%
# Data Prep
import pandas as pd

# Plotting 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # FUEL MAK RAME

# %%
f_mak_rame = pd.read_csv("data/fuel_mak_rame.csv")
print("Fuel MAK Rame")
f_mak_rame.head()
# Out:
# Fuel MAK Rame
#    month  year     quant   factory     type  supplier    unit
# 0      1  2016  16679.37  MAK_rame  Propane  Afriquia  Liters
# 1      2  2016  19886.32  MAK_rame  Propane  Afriquia  Liters
# 2      3  2016  14194.13  MAK_rame  Propane  Afriquia  Liters
# 3      4  2016  10791.60  MAK_rame  Propane  Afriquia  Liters
# 4      5  2016  19039.24  MAK_rame  Propane  Afriquia  Liters

# %%
f_mak_rame["day"] = 1
f_mak_rame["date"] = pd.to_datetime(f_mak_rame[['year', 'month', 'day']])

# %%
f_mak_rame.count()
# Out:
# month       29
# year        29
# quant       29
# factory     29
# type        29
# supplier    29
# unit        29
# day         29
# date        29
# dtype: int64

# %%
f_mak_rame.head()
# Out:
#    month  year     quant   factory     type  supplier    unit  day       date
# 0      1  2016  16679.37  MAK_rame  Propane  Afriquia  Liters    1 2016-01-01
# 1      2  2016  19886.32  MAK_rame  Propane  Afriquia  Liters    1 2016-02-01
# 2      3  2016  14194.13  MAK_rame  Propane  Afriquia  Liters    1 2016-03-01
# 3      4  2016  10791.60  MAK_rame  Propane  Afriquia  Liters    1 2016-04-01
# 4      5  2016  19039.24  MAK_rame  Propane  Afriquia  Liters    1 2016-05-01

# %% [markdown]
# ### Monthly Fuel

# %%
plt.plot(f_mak_rame.month[:12], f_mak_rame.quant[:12])
plt.plot(f_mak_rame.month[12:24], f_mak_rame.quant[12:24])
plt.plot(f_mak_rame.month[24:], f_mak_rame.quant[24:])
plt.title("Monthly Fuel: MAK Rame")
plt.xlabel("Month")
plt.ylabel("Quantitity (KG)")
plt.legend(['2016', '2017', '2018'], loc='upper right')
plt.show()

# %% [markdown]
# ### Monthly Fuel

# %%
plt.plot(f_mak_rame.date, f_mak_rame.quant)
plt.xlabel("Date")
plt.ylabel("Quantitity (KG)")
plt.title("Total Fuel: MAK Rame")
plt.show()

# %%
plt.scatter(f_mak_rame.month[:12], f_mak_rame.quant[:12])
plt.show()

# %% [markdown]
# # FUEL MAK CUT

# %%
f_mak_cut = pd.read_csv("data/fuel_mak_cut.csv")
f_mak_cut.head()
# Out:
#    month  year   quant  factory     type unit
# 0      8  2016   54.02  MAK_cut  gas_oil   Kg
# 1      9  2016  107.41  MAK_cut  gas_oil   Kg
# 2     10  2016   55.07  MAK_cut  gas_oil   Kg
# 3     11  2016   54.35  MAK_cut  gas_oil   Kg
# 4     12  2016  219.00  MAK_cut  gas_oil   Kg

# %%
f_mak_cut["day"] = 1
f_mak_cut["date"] = pd.to_datetime(f_mak_cut[['year', 'month', 'day']])

# %%
f_mak_cut.count()
# Out:
# month       23
# year        23
# quant_kg    23
# factory     23
# type        23
# day         23
# date        23
# dtype: int64

# %% [markdown]
# ### Monthly Fuel

# %%
plt.plot(f_mak_cut.month[:5], f_mak_cut.quant[:5])
plt.plot(f_mak_cut.month[5:17], f_mak_cut.quant[5:17])
plt.plot(f_mak_cut.month[17:], f_mak_cut.quant[17:])
plt.xlabel("Month")
plt.ylabel("Quantitity (KG)")
plt.title("Monthly Fuel: MAK Cut")
plt.legend(['2016', '2017', '2018'], loc='upper right')
plt.show()

# %% [markdown]
# ### Total Fuel

# %%
plt.plot(f_mak_cut.date, f_mak_cut.quant)
plt.xlabel("Date")
plt.ylabel("Quantitity (KG)")
plt.title("Total Fuel: MAK Cut")
plt.show()

# %%
plt.scatter(f_mak_cut.month[:5], f_mak_cut.quant[:5])
plt.show()

# %% [markdown]
# # FUEL SALSAPRINT

# %%
f_sp = pd.read_csv("data/fuel_salsaprint.csv")
f_sp.head()
# Out:
#    month  year  quant     factory     type supplier    unit
# 0      1  2016   3115  SalsaPrint  Propane    Total  Liters
# 1      2  2016   2930  SalsaPrint  Propane    Total  Liters
# 2      3  2016   4782  SalsaPrint  Propane    Total  Liters
# 3      4  2016   4667  SalsaPrint  Propane    Total  Liters
# 4      5  2016   1616  SalsaPrint  Propane    Total  Liters

# %%
f_sp["day"] = 1
f_sp["date"] = pd.to_datetime(f_sp[['year', 'month', 'day']])

# %%
f_sp.count()
# Out:
# month       29
# year        29
# quant       29
# factory     29
# type        29
# supplier    29
# unit        29
# day         29
# date        29
# dtype: int64

# %% [markdown]
# ### Monthly Fuel

# %%
plt.plot(f_sp.month[:12], f_sp.quant[:12])
plt.plot(f_sp.month[12:24], f_sp.quant[12:24])
plt.plot(f_sp.month[24:], f_sp.quant[24:])
plt.xlabel("Month")
plt.ylabel("Quantitity (L)")
plt.title("Monthly Fuel: SalsaPrint")
plt.legend(['2016', '2017', '2018'], loc='upper right')
plt.show()

# %% [markdown]
# ### Total Fuel

# %%
plt.plot(f_sp.date, f_sp.quant)
plt.xlabel("Date")
plt.ylabel("Quantitity (L)")
plt.title("Total Fuel: SalsaPrint")
plt.show()

# %% [markdown]
# # FUEL TINTCOLOR

# %%
f_tc_fork = pd.read_csv("data/fuel_tintcolor_fork.csv")
f_tc_fork.head()
# Out:
#    month  year  quant    factory    type    unit
# 0      1  2016    204  TintColor  Diesel  Liters
# 1      2  2016    204  TintColor  Diesel  Liters
# 2      3  2016    238  TintColor  Diesel  Liters
# 3      4  2016    238  TintColor  Diesel  Liters
# 4      5  2016     34  TintColor  Diesel  Liters

# %%
f_tc_fork["day"] = 1
f_tc_fork["date"] = pd.to_datetime(f_tc_fork[['year', 'month', 'day']])

# %%
f_tc_fork.count()
# Out:
# month      30
# year       30
# quant      30
# factory    30
# type       30
# unit       30
# day        30
# date       30
# dtype: int64

# %% [markdown]
# ### Monthly Fuel

# %%
plt.plot(f_tc_fork.month[:12], f_tc_fork.quant[:12])
plt.plot(f_tc_fork.month[12:24], f_tc_fork.quant[12:24])
plt.plot(f_tc_fork.month[24:], f_tc_fork.quant[24:])
plt.xlabel("Month")
plt.ylabel("Quantitity (L)")
plt.title("Monthly Fuel: TintColor Forklift")
plt.legend(['2016', '2017', '2018'], loc='upper right')
plt.show()

# %% [markdown]
# ### Total Fuel

# %%
plt.plot(f_tc_fork.date, f_tc_fork.quant)
plt.xlabel("Date")
plt.ylabel("Quantitity (L)")
plt.title("Total Fuel: TintColor Forklift")
plt.show()
